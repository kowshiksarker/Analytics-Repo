# %% [markdown]
# <a href="https://colab.research.google.com/github/kowshiksarker/Analytics-Repo/blob/master/Downloading_Twitter_Data_for_Text_Data_Analysis_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Installing and importing the Tweepy for accessing the Twitter API.**

# %%
! pip install tweepy
import tweepy
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %% [markdown]
# **Authenticating**
#
# Now that we have install and import *Tweepy* its time to fetch the data from Twitter using it but, before that we need to do the necessary authentication steps using the tokens that we got from Tweeter developer account. I have created an excel named *'login.csv'* which contains my 4 keys in a column simmultaneously in order. i.e.
#
# *   API Token
# *   API Secret Token
# *   Access Token
# *   Access Secret Token
#
# And I saved them in a dataframe called, *log* from where I can reuse them in my subsequent code lines.

# %%
log=pd.read_csv('login.csv')
API_KEY=log['key'][0]
API_SECRET=log['key'][1]
ACCESS_TOKEN=log['key'][2]
ACCESS_TOKEN_SECRET=log['key'][3]

# %%
auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
#wait_on_rate_limit – Whether or not to automatically wait for rate limits to replenish
#wait_on_rate_limit_notify – Whether or not to print a notification when Tweepy is waiting for rate limits to replenish
# the sleep mode is automatically enabled with above 2 args
print(api.me().name)
# Out:
# Kowshik Sarker

# %% [markdown]
# After successfull authenctication the user name will be dispalyed which now let us move forward towards the data extraction.
#
# Time to move on!!

# %% [markdown]
# Now, we can fetch data from twitter in 2 different way.
#
# 1. User specific data fecthing - We can fetch tweets of any specific user.
# 2. Word specific data fecthing - We can fetch tweets having any specific word.
#
# Let's explore these 2 method one by one.

# %% [markdown]
# 1. User Specific Tweet Fetch
#
# Here we are fetching last 100 tweets of Sachin Tendulkar and storing it in a list called *posts*.

# %%
posts=api.user_timeline(screen_name="sachin_rt",count=100,lang="en",tweet_mode="extended")

print("Show the 5 recent tweets: \n")
i=1
for tweet in posts[0:5]:
  print(str(i)+ ') ' +tweet.full_text+'\n')
  i=i+1
# Out:
# Show the 5 recent tweets:
#
# 1) I look forward to working with the new administration and leaders on both sides in Congress on getting the surging pandemic under control, engaging partners around the world on issues like poverty and climate change, and addressing issues of inequality and opportunity at home.
#
# 2) Congratulations to President-Elect Biden and Vice President-Elect Harris. Thank you to the election officials and campaign workers who worked tirelessly to ensure a record number of Americans could cast a ballot and have it counted during such an challenging time for our country.
#
# 3) Here in Washington, we always vote by mail. It's a safe and secure way to shape the future of our country. But regardless of whether you vote by mail or in person this year, I hope you plan to make your voice heard. Visit https://t.co/TmsHAC9MGv for more information.
#
# ...

# %% [markdown]
# Now we will be storing these tweets(txt data) into a dataframe so that it can be further used for analysis

# %%
df=pd.DataFrame([tweet.full_text for tweet in posts],columns=['Tweets'])

df.head()
# Out:
#                                               Tweets
# 0  I look forward to working with the new adminis...
# 1  Congratulations to President-Elect Biden and V...
# 2  Here in Washington, we always vote by mail. It...
# 3  @MohamedBinZayed The UAE is an essential partn...
# 4  For decades, @Rotary has worked tirelessly to ...

# %% [markdown]
# 2. Word Specific Tweet Fetch
#
# Here we are fetching 100 posts having a keyword called *'#swachhbharat'*
#
# As the tweets will be fetched in a json format, we need to convert that into text format and then we can store the same in a dataframe. For that wee will be needed some libraries. So installing them and importing them is a must step at first.

# %%
! pip install jsonpickle

# %%
import jsonpickle
import csv
import time
st = time.time()

tweetsPerQuery = 100 #this is the maximum provided by API
max_tweets = 100000000 # just for the sake of While loop
fName = 'tweets.txt' # where i save the tweets

# No sinceId and max_id ..Get whathever you have exhaustively
since_id = None
max_id = -1
tweet_count = 0
print("Downloading the tweeets..takes some time..")

search_query="#SwachhBharat"
x=0
with open(fName,'w') as f:
    print("Downloading hashtag" + search_query)
    while(tweet_count<max_tweets):
        try:
            if(max_id<=0):
                if(not since_id):
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended')

                else:
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended',since_id=since_id)
            else:
                if(not since_id):
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended',max_id=str(max_id-1))
                else:
                    new_tweets = api.search(q=search_query,count=tweetsPerQuery,lang="en",tweet_mode='extended',max_id=str(max_id-1),since_id=since_id)

            # Tweets Exhausted
            if(not new_tweets):
                print("No more tweets found!!")
                break
            # write all the new_tweets to a json file
            for tweet in new_tweets:
                f.write(jsonpickle.encode(tweet._json,unpicklable=False)+'\n')
                tweet_count+=len(new_tweets)
                print("Successfully downloaded {0} tweets".format(tweet_count))
                max_id=new_tweets[-1].id
        # in case of any error
        except tweepy.TweepError as e:
                print("Some error!!:"+str(e))
                break
end = time.time()

print("A total of {0} tweets are downloaded and saved to {1}".format(tweet_count,fName))
print("Total time taken is ",end-st,"seconds.")
# Out:
# ...
# Successfully downloaded 91 tweets
# Successfully downloaded 182 tweets
# Successfully downloaded 273 tweets
# Successfully downloaded 364 tweets
# Successfully downloaded 455 tweets
# Successfully downloaded 546 tweets
# Successfully downloaded 637 tweets
# Successfully downloaded 728 tweets
# Successfully downloaded 819 tweets
# Successfully downloaded 910 tweets
# Successfully downloaded 1001 tweets
# Successfully downloaded 1092 tweets
# Successfully downloaded 1183 tweets
# Successfully downloaded 1274 tweets
# Successfully downloaded 1365 tweets
# Successfully downloaded 1456 tweets
# Successfully downloaded 1547 tweets
# Successfully downloaded 1638 tweets
# Successfully downloaded 1729 tweets
# Successfully downloaded 1820 tweets
# Successfully downloaded 1911 tweets
# Successfully downloaded 2002 tweets
# Successfully downloaded 2093 tweets
# Successfully downloaded 2184 tweets
# Successfully downloaded 2275 tweets
# Successfully downloaded 2366 tweets
# ...

# %% [markdown]
# We can see that total 302266 tweets are downloaded and converted from json to txt format and saved in a txt file named 'tweets.txt'. Now its time to move this data into a dataframe for further text data analysis. Lets do it.

# %%
import json
import csv

f = open('tweets.csv','a',encoding='utf-8')
csvWriter = csv.writer(f)
headers=['full_text','retweet_count','user_followers_count','favorite_count','place','coordinates','geo','created_at','id_str']
csvWriter.writerow(headers)

for inputFile in ['tweets.txt']:#all the text-file names you want to convert to Csv in the sae folder as this code
    tweets = []
    for line in open(inputFile, 'r'):
        tweets.append(json.loads(line))

    print('HI',len(tweets))
    count_lines=0
    for tweet in tweets:
        try:
            csvWriter.writerow([tweet['full_text'],tweet['retweet_count'],tweet['user']['followers_count'],tweet['favorite_count'],tweet['place'],tweet['coordinates'],tweet['geo'],tweet['created_at'],str(tweet['id_str'])])
            count_lines+=1
        except Exception as e:
            print(e)
    print(count_lines)
# Out:
# HI 3060
# 3060

# %% [markdown]
# As the data converted and saved into a csv file named 'tweets.csv' now its time to read the csv into a dataframe as a final data collection step.

# %%
import pandas as pd
df = pd.read_csv('tweets.csv', encoding = 'unicode_escape')
df.head()
# Out:
#                                            full_text  ...               id_str
# 0  RT @blue21sky: India à¤­à¤¾à¤°à¤¤ needsðfol...  ...  1325508500395487232
# 1  RT @GreenCapsJsr: Catching up with the team me...  ...  1325507124131102721
# 2  RT @KhushnumaKashm1: (4)\nCreating awareness a...  ...  1325505918897807362
# 3  RT @VarierSangitha: @narendramodi ð®ð³The ...  ...  1325503841907826688
# 4  RT @VarierSangitha: @narendramodi ð®ð³The ...  ...  1325503034869248000
#
# [5 rows x 9 columns]

# %% [markdown]
# # ***BINGO!!***
